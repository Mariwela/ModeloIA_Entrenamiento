# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariwela/ModeloIA_Entrenamiento/blob/main/Sistemas_agentes_colaborativos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CELDA 1
# !pip install --upgrade google-genai
# !pip install beautifulsoup4 requests

# %%
# CELDA 2
import os
from google import genai
from bs4 import BeautifulSoup
import requests

# Configura tu API key de Gemini aquí
os.environ["GOOGLE_API_KEY"] = "AIzaSyCPxji0P2RhGdTAanpDKnKc2Ml13WiLWWQ"

# Crear cliente Gemini
client = genai.Client()

# %%
# CELDA 3
def extraer_texto_url(url):
    """
    Devuelve el texto limpio de una página web, evitando bloqueos con User-Agent.
    """
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) "
                      "Chrome/142.0.0.0 Safari/537.36"
    }

    response = requests.get(url, headers=headers)
    response.raise_for_status()  # levanta error si status != 200
    soup = BeautifulSoup(response.text, "html.parser")

    # Tomar solo texto visible
    textos = soup.stripped_strings
    return " ".join(textos)

# %%
# CELDA 4
def generar_resumen(prompt, modelo="gemini-2.5-flash"):
    """
    Genera texto usando Gemini a partir de un prompt.
    """
    response = client.models.generate_content(
        model=modelo,
        contents=prompt
    )
    return response.text

# %%
# CELDA 5
url = "https://es.wikipedia.org/wiki/Juegos_ol%C3%ADmpicos"

# Extraer texto de la web
texto = extraer_texto_url(url)

# Crear prompt para resumir
prompt = f"Resume en 5 líneas la siguiente información:\n\n{texto[4000:6000]}..."  # limitar para no exceder token limit

# Generar resumen con Gemini
resumen = generar_resumen(prompt)
print(resumen)
print(texto[4000:6000])
# Out:
# Aquí tienes un resumen en 5 líneas:
#
# 1.  Los Juegos Olímpicos (JJ.OO.) son el mayor evento deportivo internacional multidisciplinario, con atletas de más de doscientos países, y sus anillos son un símbolo de paz.
# 2.  Existen los de Verano e Invierno, con dos años de intervalo, inspirados en los antiguos juegos griegos celebrados en Olimpia.
# 3.  Fueron recuperados en el siglo XIX por el barón Pierre de Coubertin, quien fundó el Comité Olímpico Internacional (COI) en 1894.
# 4.  La primera edición de la era moderna se llevó a cabo en Atenas, Grecia, en 1896.
# 5.  Desde entonces, se realizan cada cuatro años en distintas ciudades del mundo, con algunas excepciones.
# ...

# %%
# CELDA 6
prompt_directo = "cuando se incorporo el judo a los juegos olimpicos?"
resumen_directo = generar_resumen(prompt_directo)
print(resumen_directo)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-20729559.py in <cell line: 0>()
#       1 # CELDA 6
#       2 prompt_directo = "cuando se incorporo el judo a los juegos olimpicos?"
# ----> 3 resumen_directo = generar_resumen(prompt_directo)
#       4 print(resumen_directo)
#
# /tmp/ipython-input-2286936838.py in generar_resumen(prompt, modelo)
#       4     Genera texto usando Gemini a partir de un prompt.
#       5     """
# ----> 6     response = client.models.generate_content(
#       7         model=modelo,
#       8         contents=prompt
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5216     while remaining_remote_calls_afc > 0:
#    5217       i += 1
# -> 5218       response = self._generate_content(
#    5219           model=model, contents=contents, config=parsed_config
# ...
